# %% [markdown]
# # Import libraries

# %%
import os
mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-7.2.0-posix-seh-rt_v5-rev1\\mingw64\\bin'
os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
import gc # Note: this is a garbage collector
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Bring in data

# %%
PATH = r"..\Raw_Data"

# %%
data = {
    'airStore':  pd.read_csv(PATH + r"\air_store_info.csv"),
    'airVisit':  pd.read_csv(PATH + r"\air_visit_data.csv"),
    'date':      pd.read_csv(PATH + r"\date_info.csv"),
    'sampleSub': pd.read_csv(PATH + r"\sample_submission.csv"),
    'storeIDs':  pd.read_csv(PATH + r"\store_id_relation.csv")    
}

# %% [markdown]
# # Preprocess data

# %%
data['date']['visit_date'] = pd.to_datetime(data['date']['calendar_date'])
data['date'].drop('calendar_date', axis = 1 , inplace=True)

# %%
data['airVisit']['visit_date'] = pd.to_datetime(data['airVisit']['visit_date'])
data['airVisit']['dow'] = data['airVisit']['visit_date'].dt.dayofweek
data['airVisit']['year'] = data['airVisit']['visit_date'].dt.year
data['airVisit']['month'] = data['airVisit']['visit_date'].dt.month

# %% [markdown]
# ## Add EWMA of visits as feature

# %% [markdown]
# Function to calculate ewm (note, found this on the competition discussion forum):

# %%
def calc_shifted_ewm(series, alpha, adjust = True):
    return series.shift().ewm(alpha = alpha, adjust = adjust).mean()

# %%
# Step below adds the ewm by day of week. Right now I'm returning a separate series so I can look at what each step does if I want to
tmp = data['airVisit'].groupby(['air_store_id','dow']).apply(lambda x: calc_shifted_ewm(x['visitors'], 0.1)) 
# This step backfills the 1st week's dow for each restaurant, otherwise it would be NaN since it's a 1-period ewma
tmp = tmp.fillna(method='bfill')
# The groupby function returns a multiIndex Series. I only need the 3rd level (original df index) to add column to original df
tmp.index = tmp.index.get_level_values(2)
# Sort index before adding back to original df
tmp = tmp.sort_index()

# %%
data['airVisit']['ewma'] = tmp

# %% [markdown]
# ## Add 'days since last' and 'days until next' holiday

# %%
# Create a 'days since holiday' feature
daysSinceList = []
daysSinceHol = 0 # initialize daysSince counter
for row in data['date']['holiday_flg']:
    if row == 1:
        daysSinceHol = 0
        daysSinceList.append(daysSinceHol)
    else:
        daysSinceHol += 1
        daysSinceList.append(daysSinceHol)
data['date']['days_since_holiday'] = daysSinceList

# %%
# Create a 'days UNTIL next holiday' feature
holidayList = list(data['date']['holiday_flg'])
daysUntilHolList = np.zeros(len(holidayList),dtype=np.int)
daysUntilHol = 0 # initialize daysUntilHol counter
for i in range(len(holidayList)-1,0,-1):
    if holidayList[i] == 1:
        daysUntilHol = 0
        daysUntilHolList[i] = daysUntilHol
    else:
        daysUntilHol += 1
        daysUntilHolList[i] = daysUntilHol        
data['date']['days_until_holiday'] = daysUntilHolList

# %% [markdown]
# ## Merge air_visits with date dframe to get holiday info

# %%
colsToMerge = ['holiday_flg','visit_date','days_until_holiday','days_since_holiday']
df_train = pd.merge(data['airVisit'], data['date'][colsToMerge], how = 'left', on = 'visit_date')

# %% [markdown]
# ## Filter only the stores that must be predicted

# %%
df_test = data['sampleSub']

df_test['visit_date'] = df_test['id'].map(lambda x: str(x).split('_')[2])
df_test['air_store_id'] = df_test['id'].map(lambda x: '_'.join(str(x).split('_')[:2]))
df_test['visit_date'] = pd.to_datetime(df_test['visit_date'])
df_test['dow'] = df_test['visit_date'].dt.dayofweek
df_test['year'] = df_test['visit_date'].dt.year
df_test['month'] = df_test['visit_date'].dt.month

unique_stores = df_test['air_store_id'].unique()
stores = pd.concat([pd.DataFrame({'air_store_id': unique_stores, 'dow': [i]*len(unique_stores)}) for i in range(7)], axis=0, ignore_index=True).reset_index(drop=True)
#stores.head()

# %% [markdown]
# ## Merge df_test with date dframe to get holiday info

# %%
df_test = pd.merge(df_test, data['date'][colsToMerge], how = 'left', on = 'visit_date')

# %%
stores = pd.merge(stores, data['airStore'], how='left', on=['air_store_id'])
#stores.head()

# %%
# Encode categorical string variables 
lbl = LabelEncoder()
stores['air_genre_name'] = lbl.fit_transform(stores['air_genre_name'])
stores['air_area_name'] = lbl.fit_transform(stores['air_area_name'])

# %% [markdown]
# ### Add genre and area to train and test data

# %%
df_train = pd.merge(df_train, stores, how = 'left', on = ['air_store_id','dow'])

# %% [markdown]
# ### Add visitor statistics as features

# %%
tmp = df_train.groupby(['air_store_id','dow']).agg({'visitors' : [np.min,np.mean,np.median,np.max,np.size]}).reset_index()
tmp.columns = ['air_store_id', 'dow', 'min_visitors', 'mean_visitors', 'median_visitors','max_visitors','count_observations']
df_train = pd.merge(df_train, tmp, how='left', on=['air_store_id','dow'])

# %%
df_test = pd.merge(df_test, stores, how = 'left', on = ['air_store_id','dow'])

# %%
df_test = pd.merge(df_test, tmp, how='left', on=['air_store_id','dow'])

# %% [markdown]
# Note: For XGB, didn't fillna (1/28/2018)
# Other algorithms need fillna. TODO: 1) investigate why there are NaN on train set. 2) Check if XGBoost gets better score with fillna

# %%
#df_train = df_train.fillna(-1)
#df_test = df_test.fillna(-1)

# %%
train = df_train
test = df_test
col = [c for c in train if c not in ['id', 'air_store_id','visit_date','visitors']]

# %% [markdown]
# # Initialize XGBoost
# Note - code based on:
#
# https://www.kaggle.com/jmbull/no-xgb-starter-here-s-one-lb-507
#
# and
#
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %%
# XGB starter template borrowed from @anokas
# https://www.kaggle.com/anokas/simple-xgboost-starter-0-0655

print('Binding to float32')

for c, dtype in zip(df_train.columns, train.dtypes):
    if dtype == np.float64:
        train[c] = train[c].astype(np.float32)
        
for c, dtype in zip(df_test.columns, test.dtypes):
    if dtype == np.float64:
        test[c] = test[c].astype(np.float32)
# Out:
# Binding to float32

# %%
def modelfit(alg, dtrain, predictors, useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain[target].values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
            metrics='auc', early_stopping_rounds=early_stopping_rounds, show_progress=False)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain['visitors'],eval_metric='valid-rmse')
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
        
    #Print model report:
    print("\nModel Report")
    print("Accuracy : %.4g" % metrics.accuracy_score(dtrain['visitors'].values, dtrain_predictions))
    print("AUC Score (Train): %f" % metrics.roc_auc_score(dtrain['visitors'], dtrain_predprob))
                    
    feat_imp = pd.Series(alg.booster().get_fscore()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')
    plt.ylabel('Feature Importance Score')

# %%
# Set arguments for modelfit function:
predictors = columnsForTest_df
target = ['visitors']

# %% [markdown]
# ### Use cell below for validation using same weeks as test set but in the 2016 year

# %%
# Create training / validation split based on weeks in test set
x_train_setup = train.set_index('visit_date')

x_valid = x_train_setup['2016-04-23':'2016-05-31'].reset_index()
x_train = pd.concat([x_train_setup['2016-01-01':'2016-04-22'],
                     x_train_setup['2016-05-01':'2017-04-22']]).reset_index()

# Note: taking the absolute values makes the training take a VERY long time. I will instead take the log values
#y_train = x_train['visitors']
#y_valid = x_valid['visitors']

y_train = np.log1p(x_train['visitors'].values)
y_valid = np.log1p(x_valid['visitors'].values)

x_train = x_train.drop(['air_store_id','visit_date','visitors'], axis=1)
x_valid = x_valid.drop(['air_store_id','visit_date','visitors'], axis=1)

# Get Column order for x_test df
colOrder = x_train.columns

# %% [markdown]
# ### Use cell below for validation using split based on last rows in train dataframe

# %%
#x_train = train.drop(['air_store_id','visit_date','visitors'], axis=1)
#y_train = np.log1p(train['visitors'].values)

# Get Column order for x_test df
#colOrder = x_train.columns

# %%
# Create training / validation split
#split = 200000
#x_train, y_train, x_valid, y_valid = x_train[:split], y_train[:split], x_train[split:], y_train[split:]

#print('Building DMatrix...')

# %%
d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)

#del x_train, x_valid; gc.collect()

# %%
print('Training ...')

params = {}
params['objective'] = 'reg:linear'
params['eval_metric'] = 'rmse'
params['eta'] = 0.04
params['max_depth'] = 7
params['silent'] = 1

watchlist = [(d_train, 'train'), (d_valid, 'valid')]
clf = xgb.train(params, d_train, 10000, watchlist, early_stopping_rounds=100, verbose_eval=25)

#del d_train, d_valid
# Out:
# Training ...
# [0]	train-rmse:2.34605	valid-rmse:2.40688
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# [25]	train-rmse:0.968854	valid-rmse:1.01216
# [50]	train-rmse:0.583087	valid-rmse:0.611487
# [75]	train-rmse:0.508155	valid-rmse:0.526988
# [100]	train-rmse:0.494251	valid-rmse:0.507301
# [125]	train-rmse:0.48997	valid-rmse:0.498913
# [150]	train-rmse:0.487118	valid-rmse:0.494258
# [175]	train-rmse:0.484867	valid-rmse:0.489813
# [200]	train-rmse:0.483301	valid-rmse:0.48626
# [225]	train-rmse:0.481949	valid-rmse:0.484079
# [250]	train-rmse:0.480745	valid-rmse:0.481847
# [275]	train-rmse:0.479597	valid-rmse:0.48031
# [300]	train-rmse:0.478678	valid-rmse:0.479035
# [325]	train-rmse:0.477651	valid-rmse:0.475766
# [350]	train-rmse:0.476427	valid-rmse:0.473319
# [375]	train-rmse:0.475133	valid-rmse:0.470467
# [400]	train-rmse:0.474129	valid-rmse:0.469396
# [425]	train-rmse:0.473204	valid-rmse:0.46799
# [450]	train-rmse:0.472222	valid-rmse:0.465909
# [475]	train-rmse:0.471337	valid-rmse:0.464997
# [500]	train-rmse:0.470161	valid-rmse:0.462946
# [525]	train-rmse:0.469199	valid-rmse:0.462318
# [550]	train-rmse:0.468322	valid-rmse:0.459662
# [575]	train-rmse:0.467367	valid-rmse:0.456869
# [600]	train-rmse:0.466409	valid-rmse:0.454249
# [625]	train-rmse:0.465436	valid-rmse:0.453407
# [650]	train-rmse:0.464398	valid-rmse:0.452542
# [675]	train-rmse:0.46359	valid-rmse:0.451407
# [700]	train-rmse:0.462732	valid-rmse:0.450594
# [725]	train-rmse:0.461828	valid-rmse:0.450035
# [750]	train-rmse:0.460966	valid-rmse:0.449485
# [775]	train-rmse:0.460138	valid-rmse:0.448904
# [800]	train-rmse:0.459441	valid-rmse:0.448375
# [825]	train-rmse:0.458635	valid-rmse:0.447512
# [850]	train-rmse:0.457815	valid-rmse:0.446803
# [875]	train-rmse:0.4568	valid-rmse:0.445419
# [900]	train-rmse:0.455974	valid-rmse:0.443514
# [925]	train-rmse:0.455107	valid-rmse:0.442281
# [950]	train-rmse:0.454506	valid-rmse:0.441529
# [975]	train-rmse:0.453763	valid-rmse:0.440891
# [1000]	train-rmse:0.453122	valid-rmse:0.44031
# [1025]	train-rmse:0.452328	valid-rmse:0.439508
# [1050]	train-rmse:0.451416	valid-rmse:0.438794
# [1075]	train-rmse:0.450729	valid-rmse:0.438414
# [1100]	train-rmse:0.449998	valid-rmse:0.437852
# [1125]	train-rmse:0.449306	valid-rmse:0.437289
# [1150]	train-rmse:0.4486	valid-rmse:0.436595
# [1175]	train-rmse:0.447792	valid-rmse:0.435911
# [1200]	train-rmse:0.447094	valid-rmse:0.435365
# [1225]	train-rmse:0.446548	valid-rmse:0.435102
# [1250]	train-rmse:0.445723	valid-rmse:0.434223
# [1275]	train-rmse:0.44491	valid-rmse:0.433511
# [1300]	train-rmse:0.444191	valid-rmse:0.432962
# [1325]	train-rmse:0.443484	valid-rmse:0.43206
# [1350]	train-rmse:0.442864	valid-rmse:0.431309
# [1375]	train-rmse:0.44208	valid-rmse:0.43066
# [1400]	train-rmse:0.441493	valid-rmse:0.429785
# [1425]	train-rmse:0.440803	valid-rmse:0.42919
# [1450]	train-rmse:0.440057	valid-rmse:0.428422
# [1475]	train-rmse:0.439349	valid-rmse:0.427838
# [1500]	train-rmse:0.438624	valid-rmse:0.427194
# [1525]	train-rmse:0.437959	valid-rmse:0.426626
# [1550]	train-rmse:0.437215	valid-rmse:0.425651
# [1575]	train-rmse:0.436413	valid-rmse:0.42494
# [1600]	train-rmse:0.435839	valid-rmse:0.424276
# [1625]	train-rmse:0.43518	valid-rmse:0.423072
# [1650]	train-rmse:0.434388	valid-rmse:0.422437
# [1675]	train-rmse:0.433863	valid-rmse:0.422098
# [1700]	train-rmse:0.43334	valid-rmse:0.42156
# [1725]	train-rmse:0.432882	valid-rmse:0.420364
# [1750]	train-rmse:0.432266	valid-rmse:0.419063
# [1775]	train-rmse:0.43185	valid-rmse:0.418643
# [1800]	train-rmse:0.431425	valid-rmse:0.418321
# [1825]	train-rmse:0.430881	valid-rmse:0.417313
# [1850]	train-rmse:0.430304	valid-rmse:0.416079
# [1875]	train-rmse:0.429639	valid-rmse:0.415682
# [1900]	train-rmse:0.428987	valid-rmse:0.414602
# [1925]	train-rmse:0.428484	valid-rmse:0.413853
# [1950]	train-rmse:0.427677	valid-rmse:0.413237
# [1975]	train-rmse:0.426922	valid-rmse:0.412473
# [2000]	train-rmse:0.426275	valid-rmse:0.412019
# [2025]	train-rmse:0.425741	valid-rmse:0.411637
# [2050]	train-rmse:0.425192	valid-rmse:0.411249
# [2075]	train-rmse:0.424562	valid-rmse:0.410775
# [2100]	train-rmse:0.424053	valid-rmse:0.410373
# [2125]	train-rmse:0.423554	valid-rmse:0.409975
# [2150]	train-rmse:0.423099	valid-rmse:0.40972
# [2175]	train-rmse:0.422555	valid-rmse:0.409193
# [2200]	train-rmse:0.421836	valid-rmse:0.408589
# [2225]	train-rmse:0.421176	valid-rmse:0.407616
# [2250]	train-rmse:0.420673	valid-rmse:0.40707
# [2275]	train-rmse:0.420172	valid-rmse:0.406596
# [2300]	train-rmse:0.419706	valid-rmse:0.406205
# [2325]	train-rmse:0.419094	valid-rmse:0.405898
# [2350]	train-rmse:0.418563	valid-rmse:0.405402
# [2375]	train-rmse:0.418004	valid-rmse:0.404378
# [2400]	train-rmse:0.417402	valid-rmse:0.403642
# [2425]	train-rmse:0.416804	valid-rmse:0.403126
# [2450]	train-rmse:0.416161	valid-rmse:0.402533
# [2475]	train-rmse:0.415488	valid-rmse:0.402074
# [2500]	train-rmse:0.41485	valid-rmse:0.401242
# [2525]	train-rmse:0.414335	valid-rmse:0.400729
# [2550]	train-rmse:0.413673	valid-rmse:0.400127
# [2575]	train-rmse:0.413184	valid-rmse:0.399609
# [2600]	train-rmse:0.412748	valid-rmse:0.39899
# [2625]	train-rmse:0.412378	valid-rmse:0.398774
# [2650]	train-rmse:0.411833	valid-rmse:0.398403
# [2675]	train-rmse:0.411213	valid-rmse:0.398027
# [2700]	train-rmse:0.410779	valid-rmse:0.397705
# [2725]	train-rmse:0.410295	valid-rmse:0.397287
# [2750]	train-rmse:0.409814	valid-rmse:0.396795
# [2775]	train-rmse:0.409265	valid-rmse:0.396132
# [2800]	train-rmse:0.408712	valid-rmse:0.395476
# [2825]	train-rmse:0.40827	valid-rmse:0.394929
# [2850]	train-rmse:0.40761	valid-rmse:0.394492
# [2875]	train-rmse:0.407159	valid-rmse:0.394013
# [2900]	train-rmse:0.406638	valid-rmse:0.393691
# [2925]	train-rmse:0.406184	valid-rmse:0.393406
# [2950]	train-rmse:0.4056	valid-rmse:0.392418
# [2975]	train-rmse:0.405175	valid-rmse:0.392159
# [3000]	train-rmse:0.404727	valid-rmse:0.391806
# [3025]	train-rmse:0.404324	valid-rmse:0.391243
# [3050]	train-rmse:0.404014	valid-rmse:0.390346
# [3075]	train-rmse:0.403686	valid-rmse:0.389791
# [3100]	train-rmse:0.403321	valid-rmse:0.389544
# [3125]	train-rmse:0.40286	valid-rmse:0.389247
# [3150]	train-rmse:0.402408	valid-rmse:0.388919
# [3175]	train-rmse:0.402053	valid-rmse:0.38848
# [3200]	train-rmse:0.401713	valid-rmse:0.388275
# [3225]	train-rmse:0.401338	valid-rmse:0.38806
# [3250]	train-rmse:0.400924	valid-rmse:0.387831
# [3275]	train-rmse:0.400373	valid-rmse:0.387177
# [3300]	train-rmse:0.399888	valid-rmse:0.386747
# [3325]	train-rmse:0.399417	valid-rmse:0.386439
# [3350]	train-rmse:0.398901	valid-rmse:0.386024
# [3375]	train-rmse:0.398523	valid-rmse:0.385679
# [3400]	train-rmse:0.398118	valid-rmse:0.385364
# [3425]	train-rmse:0.397671	valid-rmse:0.384893
# [3450]	train-rmse:0.397249	valid-rmse:0.384647
# [3475]	train-rmse:0.396777	valid-rmse:0.38425
# [3500]	train-rmse:0.396414	valid-rmse:0.382905
# [3525]	train-rmse:0.395984	valid-rmse:0.381868
# [3550]	train-rmse:0.395576	valid-rmse:0.381617
# [3575]	train-rmse:0.395276	valid-rmse:0.381444
# [3600]	train-rmse:0.394888	valid-rmse:0.38118
# [3625]	train-rmse:0.394398	valid-rmse:0.380886
# [3650]	train-rmse:0.394017	valid-rmse:0.380653
# [3675]	train-rmse:0.393616	valid-rmse:0.380468
# [3700]	train-rmse:0.393274	valid-rmse:0.380225
# [3725]	train-rmse:0.392936	valid-rmse:0.380073
# [3750]	train-rmse:0.392521	valid-rmse:0.379854
# [3775]	train-rmse:0.392097	valid-rmse:0.379382
# [3800]	train-rmse:0.391683	valid-rmse:0.37913
# [3825]	train-rmse:0.391228	valid-rmse:0.378826
# [3850]	train-rmse:0.390761	valid-rmse:0.378677
# [3875]	train-rmse:0.390426	valid-rmse:0.378511
# [3900]	train-rmse:0.390069	valid-rmse:0.378101
# [3925]	train-rmse:0.38958	valid-rmse:0.377742
# [3950]	train-rmse:0.389102	valid-rmse:0.37744
# [3975]	train-rmse:0.388719	valid-rmse:0.377264
# [4000]	train-rmse:0.388291	valid-rmse:0.376989
# [4025]	train-rmse:0.387933	valid-rmse:0.376819
# [4050]	train-rmse:0.387501	valid-rmse:0.376607
# [4075]	train-rmse:0.3871	valid-rmse:0.37646
# [4100]	train-rmse:0.386732	valid-rmse:0.376305
# [4125]	train-rmse:0.38631	valid-rmse:0.375598
# [4150]	train-rmse:0.385988	valid-rmse:0.375495
# [4175]	train-rmse:0.385714	valid-rmse:0.375293
# [4200]	train-rmse:0.385288	valid-rmse:0.374854
# [4225]	train-rmse:0.384844	valid-rmse:0.374561
# [4250]	train-rmse:0.384415	valid-rmse:0.374277
# [4275]	train-rmse:0.383932	valid-rmse:0.373196
# [4300]	train-rmse:0.383582	valid-rmse:0.372254
# [4325]	train-rmse:0.383266	valid-rmse:0.371718
# [4350]	train-rmse:0.382863	valid-rmse:0.37148
# [4375]	train-rmse:0.382627	valid-rmse:0.371296
# [4400]	train-rmse:0.382206	valid-rmse:0.371135
# [4425]	train-rmse:0.381834	valid-rmse:0.370625
# [4450]	train-rmse:0.381513	valid-rmse:0.370451
# [4475]	train-rmse:0.381106	valid-rmse:0.370264
# [4500]	train-rmse:0.380719	valid-rmse:0.370009
# [4525]	train-rmse:0.380477	valid-rmse:0.369844
# [4550]	train-rmse:0.380279	valid-rmse:0.369718
# [4575]	train-rmse:0.379903	valid-rmse:0.369498
# [4600]	train-rmse:0.379636	valid-rmse:0.369314
# [4625]	train-rmse:0.379318	valid-rmse:0.369025
# [4650]	train-rmse:0.378985	valid-rmse:0.368857
# [4675]	train-rmse:0.37859	valid-rmse:0.368662
# [4700]	train-rmse:0.378298	valid-rmse:0.368355
# [4725]	train-rmse:0.377995	valid-rmse:0.368072
# [4750]	train-rmse:0.377557	valid-rmse:0.367747
# [4775]	train-rmse:0.377154	valid-rmse:0.367386
# [4800]	train-rmse:0.376788	valid-rmse:0.366878
# [4825]	train-rmse:0.376449	valid-rmse:0.366348
# [4850]	train-rmse:0.3761	valid-rmse:0.36622
# [4875]	train-rmse:0.37573	valid-rmse:0.365261
# [4900]	train-rmse:0.375418	valid-rmse:0.365044
# [4925]	train-rmse:0.374982	valid-rmse:0.364797
# [4950]	train-rmse:0.374608	valid-rmse:0.364597
# [4975]	train-rmse:0.374137	valid-rmse:0.364389
# [5000]	train-rmse:0.373703	valid-rmse:0.364138
# [5025]	train-rmse:0.37336	valid-rmse:0.363838
# [5050]	train-rmse:0.372917	valid-rmse:0.363264
# [5075]	train-rmse:0.372608	valid-rmse:0.363022
# [5100]	train-rmse:0.372167	valid-rmse:0.362265
# [5125]	train-rmse:0.3717	valid-rmse:0.361943
# [5150]	train-rmse:0.371287	valid-rmse:0.361547
# [5175]	train-rmse:0.370875	valid-rmse:0.36118
# [5200]	train-rmse:0.370506	valid-rmse:0.360959
# [5225]	train-rmse:0.370084	valid-rmse:0.36066
# [5250]	train-rmse:0.369693	valid-rmse:0.3604
# [5275]	train-rmse:0.369242	valid-rmse:0.360147
# [5300]	train-rmse:0.368775	valid-rmse:0.359905
# [5325]	train-rmse:0.368409	valid-rmse:0.359682
# [5350]	train-rmse:0.368031	valid-rmse:0.35948
# [5375]	train-rmse:0.36766	valid-rmse:0.359316
# [5400]	train-rmse:0.367386	valid-rmse:0.359192
# [5425]	train-rmse:0.367021	valid-rmse:0.359007
# [5450]	train-rmse:0.366679	valid-rmse:0.358842
# [5475]	train-rmse:0.366386	valid-rmse:0.358727
# [5500]	train-rmse:0.365913	valid-rmse:0.358445
# [5525]	train-rmse:0.365518	valid-rmse:0.358211
# [5550]	train-rmse:0.365237	valid-rmse:0.358005
# [5575]	train-rmse:0.364871	valid-rmse:0.357683
# [5600]	train-rmse:0.364553	valid-rmse:0.357528
# [5625]	train-rmse:0.364201	valid-rmse:0.357167
# [5650]	train-rmse:0.363849	valid-rmse:0.356659
# [5675]	train-rmse:0.363578	valid-rmse:0.356408
# [5700]	train-rmse:0.363135	valid-rmse:0.355928
# [5725]	train-rmse:0.362764	valid-rmse:0.355419
# [5750]	train-rmse:0.362442	valid-rmse:0.355072
# [5775]	train-rmse:0.36214	valid-rmse:0.354822
# [5800]	train-rmse:0.361817	valid-rmse:0.354488
# [5825]	train-rmse:0.36144	valid-rmse:0.354216
# [5850]	train-rmse:0.361089	valid-rmse:0.353636
# [5875]	train-rmse:0.360853	valid-rmse:0.353526
# [5900]	train-rmse:0.360458	valid-rmse:0.353298
# [5925]	train-rmse:0.360172	valid-rmse:0.353163
# [5950]	train-rmse:0.359935	valid-rmse:0.353109
# [5975]	train-rmse:0.359606	valid-rmse:0.352977
# [6000]	train-rmse:0.359337	valid-rmse:0.352751
# [6025]	train-rmse:0.359039	valid-rmse:0.352574
# [6050]	train-rmse:0.358748	valid-rmse:0.352472
# [6075]	train-rmse:0.358382	valid-rmse:0.352349
# [6100]	train-rmse:0.358028	valid-rmse:0.351884
# [6125]	train-rmse:0.357784	valid-rmse:0.351436
# [6150]	train-rmse:0.357454	valid-rmse:0.351303
# [6175]	train-rmse:0.357082	valid-rmse:0.351028
# [6200]	train-rmse:0.356719	valid-rmse:0.350754
# [6225]	train-rmse:0.356381	valid-rmse:0.350613
# [6250]	train-rmse:0.355944	valid-rmse:0.350389
# [6275]	train-rmse:0.355655	valid-rmse:0.349751
# [6300]	train-rmse:0.3554	valid-rmse:0.34918
# [6325]	train-rmse:0.355045	valid-rmse:0.348577
# [6350]	train-rmse:0.354596	valid-rmse:0.348293
# [6375]	train-rmse:0.354256	valid-rmse:0.348152
# [6400]	train-rmse:0.353989	valid-rmse:0.348015
# [6425]	train-rmse:0.353772	valid-rmse:0.347724
# [6450]	train-rmse:0.35349	valid-rmse:0.346599
# [6475]	train-rmse:0.353265	valid-rmse:0.345036
# [6500]	train-rmse:0.352961	valid-rmse:0.344672
# [6525]	train-rmse:0.352687	valid-rmse:0.344513
# [6550]	train-rmse:0.352348	valid-rmse:0.3442
# [6575]	train-rmse:0.351966	valid-rmse:0.343874
# [6600]	train-rmse:0.351558	valid-rmse:0.343599
# [6625]	train-rmse:0.351136	valid-rmse:0.343402
# [6650]	train-rmse:0.350812	valid-rmse:0.34325
# [6675]	train-rmse:0.350554	valid-rmse:0.343132
# [6700]	train-rmse:0.35025	valid-rmse:0.34298
# [6725]	train-rmse:0.349956	valid-rmse:0.342873
# [6750]	train-rmse:0.349628	valid-rmse:0.342692
# [6775]	train-rmse:0.349232	valid-rmse:0.342359
# [6800]	train-rmse:0.348884	valid-rmse:0.342148
# [6825]	train-rmse:0.348579	valid-rmse:0.341974
# [6850]	train-rmse:0.348323	valid-rmse:0.341872
# [6875]	train-rmse:0.348029	valid-rmse:0.341721
# [6900]	train-rmse:0.347792	valid-rmse:0.341607
# [6925]	train-rmse:0.347589	valid-rmse:0.341537
# [6950]	train-rmse:0.347393	valid-rmse:0.341437
# [6975]	train-rmse:0.347006	valid-rmse:0.341162
# [7000]	train-rmse:0.346644	valid-rmse:0.341067
# [7025]	train-rmse:0.346237	valid-rmse:0.340816
# [7050]	train-rmse:0.345898	valid-rmse:0.340178
# [7075]	train-rmse:0.34554	valid-rmse:0.339925
# [7100]	train-rmse:0.345179	valid-rmse:0.339312
# [7125]	train-rmse:0.344896	valid-rmse:0.339244
# [7150]	train-rmse:0.344612	valid-rmse:0.339126
# [7175]	train-rmse:0.344345	valid-rmse:0.339012
# [7200]	train-rmse:0.343945	valid-rmse:0.338699
# [7225]	train-rmse:0.343632	valid-rmse:0.33849
# [7250]	train-rmse:0.343379	valid-rmse:0.338349
# [7275]	train-rmse:0.343067	valid-rmse:0.338116
# [7300]	train-rmse:0.342721	valid-rmse:0.337911
# [7325]	train-rmse:0.342443	valid-rmse:0.337749
# [7350]	train-rmse:0.342197	valid-rmse:0.337663
# [7375]	train-rmse:0.341808	valid-rmse:0.337501
# [7400]	train-rmse:0.341439	valid-rmse:0.337353
# [7425]	train-rmse:0.341097	valid-rmse:0.33716
# [7450]	train-rmse:0.340745	valid-rmse:0.33692
# [7475]	train-rmse:0.340514	valid-rmse:0.336769
# [7500]	train-rmse:0.340258	valid-rmse:0.336644
# [7525]	train-rmse:0.339935	valid-rmse:0.336464
# [7550]	train-rmse:0.339613	valid-rmse:0.33634
# [7575]	train-rmse:0.339292	valid-rmse:0.336156
# [7600]	train-rmse:0.339036	valid-rmse:0.336022
# [7625]	train-rmse:0.338707	valid-rmse:0.335678
# [7650]	train-rmse:0.33843	valid-rmse:0.335578
# [7675]	train-rmse:0.338128	valid-rmse:0.335491
# [7700]	train-rmse:0.337763	valid-rmse:0.33536
# [7725]	train-rmse:0.337514	valid-rmse:0.335247
# [7750]	train-rmse:0.33723	valid-rmse:0.334899
# [7775]	train-rmse:0.336938	valid-rmse:0.334781
# [7800]	train-rmse:0.336643	valid-rmse:0.33453
# [7825]	train-rmse:0.336302	valid-rmse:0.334368
# [7850]	train-rmse:0.335955	valid-rmse:0.334165
# [7875]	train-rmse:0.33562	valid-rmse:0.333995
# [7900]	train-rmse:0.335345	valid-rmse:0.333863
# [7925]	train-rmse:0.335181	valid-rmse:0.333751
# [7950]	train-rmse:0.334875	valid-rmse:0.333634
# [7975]	train-rmse:0.334627	valid-rmse:0.33336
# [8000]	train-rmse:0.334421	valid-rmse:0.333236
# [8025]	train-rmse:0.334104	valid-rmse:0.33311
# [8050]	train-rmse:0.333781	valid-rmse:0.332996
# [8075]	train-rmse:0.333585	valid-rmse:0.332905
# [8100]	train-rmse:0.333338	valid-rmse:0.332819
# [8125]	train-rmse:0.33306	valid-rmse:0.33275
# [8150]	train-rmse:0.33284	valid-rmse:0.332681
# [8175]	train-rmse:0.332504	valid-rmse:0.332554
# [8200]	train-rmse:0.332233	valid-rmse:0.332436
# [8225]	train-rmse:0.331982	valid-rmse:0.332313
# [8250]	train-rmse:0.331704	valid-rmse:0.33222
# [8275]	train-rmse:0.3314	valid-rmse:0.332017
# [8300]	train-rmse:0.331055	valid-rmse:0.331788
# [8325]	train-rmse:0.330672	valid-rmse:0.331599
# [8350]	train-rmse:0.330242	valid-rmse:0.331035
# [8375]	train-rmse:0.329838	valid-rmse:0.330866
# [8400]	train-rmse:0.329583	valid-rmse:0.330745
# [8425]	train-rmse:0.329312	valid-rmse:0.330459
# [8450]	train-rmse:0.329097	valid-rmse:0.329998
# [8475]	train-rmse:0.328754	valid-rmse:0.329874
# [8500]	train-rmse:0.328454	valid-rmse:0.329788
# [8525]	train-rmse:0.328016	valid-rmse:0.329684
# [8550]	train-rmse:0.327642	valid-rmse:0.329507
# [8575]	train-rmse:0.327379	valid-rmse:0.329417
# [8600]	train-rmse:0.327147	valid-rmse:0.329334
# [8625]	train-rmse:0.3269	valid-rmse:0.329215
# [8650]	train-rmse:0.326594	valid-rmse:0.329031
# [8675]	train-rmse:0.326377	valid-rmse:0.328938
# [8700]	train-rmse:0.326081	valid-rmse:0.328776
# [8725]	train-rmse:0.325815	valid-rmse:0.328665
# [8750]	train-rmse:0.325528	valid-rmse:0.328556
# [8775]	train-rmse:0.325279	valid-rmse:0.328493
# [8800]	train-rmse:0.32505	valid-rmse:0.328401
# [8825]	train-rmse:0.324731	valid-rmse:0.328063
# [8850]	train-rmse:0.324496	valid-rmse:0.327862
# [8875]	train-rmse:0.324344	valid-rmse:0.32781
# [8900]	train-rmse:0.324053	valid-rmse:0.327657
# [8925]	train-rmse:0.323748	valid-rmse:0.32758
# [8950]	train-rmse:0.323487	valid-rmse:0.327332
# [8975]	train-rmse:0.323263	valid-rmse:0.327039
# [9000]	train-rmse:0.323048	valid-rmse:0.326969
# [9025]	train-rmse:0.322791	valid-rmse:0.326821
# [9050]	train-rmse:0.322505	valid-rmse:0.326373
# [9075]	train-rmse:0.322236	valid-rmse:0.325967
# [9100]	train-rmse:0.321925	valid-rmse:0.32563
# [9125]	train-rmse:0.321673	valid-rmse:0.325466
# [9150]	train-rmse:0.3214	valid-rmse:0.32517
# [9175]	train-rmse:0.321194	valid-rmse:0.324985
# [9200]	train-rmse:0.321008	valid-rmse:0.324755
# [9225]	train-rmse:0.320819	valid-rmse:0.324675
# [9250]	train-rmse:0.320595	valid-rmse:0.324582
# [9275]	train-rmse:0.320282	valid-rmse:0.324283
# [9300]	train-rmse:0.319993	valid-rmse:0.323972
# [9325]	train-rmse:0.319752	valid-rmse:0.323858
# [9350]	train-rmse:0.319489	valid-rmse:0.323712
# [9375]	train-rmse:0.31922	valid-rmse:0.323506
# [9400]	train-rmse:0.318973	valid-rmse:0.323392
# [9425]	train-rmse:0.318542	valid-rmse:0.323216
# [9450]	train-rmse:0.318144	valid-rmse:0.323001
# [9475]	train-rmse:0.317767	valid-rmse:0.32279
# [9500]	train-rmse:0.317468	valid-rmse:0.322688
# [9525]	train-rmse:0.317199	valid-rmse:0.322342
# [9550]	train-rmse:0.316884	valid-rmse:0.322174
# [9575]	train-rmse:0.316622	valid-rmse:0.322074
# [9600]	train-rmse:0.31635	valid-rmse:0.32185
# [9625]	train-rmse:0.315988	valid-rmse:0.321659
# [9650]	train-rmse:0.315688	valid-rmse:0.321272
# [9675]	train-rmse:0.315428	valid-rmse:0.32089
# [9700]	train-rmse:0.315148	valid-rmse:0.320539
# [9725]	train-rmse:0.314914	valid-rmse:0.320221
# [9750]	train-rmse:0.314631	valid-rmse:0.320061
# [9775]	train-rmse:0.314473	valid-rmse:0.319985
# [9800]	train-rmse:0.314152	valid-rmse:0.319825
# [9825]	train-rmse:0.313886	valid-rmse:0.319722
# [9850]	train-rmse:0.313574	valid-rmse:0.319605
# [9875]	train-rmse:0.313291	valid-rmse:0.319277
# [9900]	train-rmse:0.312926	valid-rmse:0.319046
# [9925]	train-rmse:0.312626	valid-rmse:0.318919
# [9950]	train-rmse:0.312389	valid-rmse:0.318812
# [9975]	train-rmse:0.312129	valid-rmse:0.318532
# [9999]	train-rmse:0.31181	valid-rmse:0.318322

# %%
#print(clf.feature_names)
xgb.plot_tree(clf, num_trees=0,rankdir='LR')
fig = plt.gcf()
fig.set_size_inches(150, 100)
fig.savefig('tree.png')

# %%
xgb.plot_importance(clf)

# %% [markdown]
# # Save the XBoost trained model

# %%
import pickle

# %%
pickle.dump(clf, open("recruit_rest_xgb.pickle.dat","wb"))

# %% [markdown]
# NOTE: To later retrieve the trained model, use command below:
#
# taken from:
# https://machinelearningmastery.com/save-gradient-boosting-models-xgboost-python/

# %%
load_model = pickle.load(open("recruit_rest_xgb.pickle.dat","rb"))

# %% [markdown]
# #### Use ewma feature in test set
# 1. Assign ewma to 1st week of test set using last week of training
# 2. Predict
# 3. Calc ewma for 2nd week of test set
# 4. predict again

# %%
# Get dataframe for last week of training set and only use store
x_train_lastWk = train[['air_store_id','visit_date','dow','ewma']]
x_train_lastWk = x_train_lastWk[x_train_lastWk['visit_date'] > '2017-04-15']

# %%
# Split test by weeks [note that weeks start on day 6 (Sunday) rather than day 0 (Monday)]
test.index = test['visit_date']

testWk1 = test['2017-04-23':'2017-04-29']
testWk2 = test['2017-04-30':'2017-05-06']
testWk3 = test['2017-05-07':'2017-05-13']
testWk4 = test['2017-05-14':'2017-05-20']
testWk5 = test['2017-05-21':'2017-05-27']
testWk6 = test['2017-05-28':'2017-06-01']

# %%
testWk1_pred = pd.merge(testWk1, x_train_lastWk.drop('visit_date',axis=1),how='left',on=['air_store_id','dow'])

# %%
#testWk1_pred['ewma'] = testWk1_pred['ewma'].fillna(value=0)

# %%
testWk1_pred.head()
# Out:
#                                 id   visitors visit_date  \
# 0  air_00a91d42b08b08d9_2017-04-23   1.580305 2017-04-23
# 1  air_00a91d42b08b08d9_2017-04-24  26.866081 2017-04-24
# 2  air_00a91d42b08b08d9_2017-04-25  19.095001 2017-04-25
# 3  air_00a91d42b08b08d9_2017-04-26  25.439875 2017-04-26
# 4  air_00a91d42b08b08d9_2017-04-27  29.720154 2017-04-27
#
#            air_store_id  dow  year  month  holiday_flg  days_until_holiday  \
# 0  air_00a91d42b08b08d9    6  2017      4            0                   6
# 1  air_00a91d42b08b08d9    0  2017      4            0                   5
# 2  air_00a91d42b08b08d9    1  2017      4            0                   4
# 3  air_00a91d42b08b08d9    2  2017      4            0                   3
# 4  air_00a91d42b08b08d9    3  2017      4            0                   2
#
#    days_since_holiday  air_genre_name  air_area_name   latitude   longitude  \
# 0                  34               6             44  35.694003  139.753595
# 1                  35               6             44  35.694003  139.753595
# 2                  36               6             44  35.694003  139.753595
# 3                  37               6             44  35.694003  139.753595
# 4                  38               6             44  35.694003  139.753595
#
#    min_visitors  mean_visitors  median_visitors  max_visitors  \
# 0           2.0       2.000000              2.0           2.0
# 1           1.0      22.457143             19.0          47.0
# 2           1.0      24.350000             24.5          43.0
# 3          15.0      28.125000             28.0          52.0
# 4          15.0      29.868421             30.0          47.0
#
#    count_observations       ewma
# 0                 1.0        NaN
# 1                35.0  26.222269
# 2                40.0  28.152105
# 3                40.0  30.854063
# 4                38.0  31.470685

# %% [markdown]
# Command to put columns in the right order for the XGBoost prediction

# %%
# NOTE: USE COLUMN LIST BELOW IF NOT INCLUDING VISITOR STATISTICS IN TRAINING SET

#columnsForTest_df = ['dow', 'year', 'month', 'ewma', 'holiday_flg', 'days_until_holiday',
#       'days_since_holiday', 'air_genre_name', 'air_area_name', 'latitude',
#       'longitude']

# NOTE: USE COLUMN LIST BELOW IF INCLUDING VISITOR STATISTICS IN TRAINING SET
columnsForTest_df = ['dow', 'year', 'month', 'ewma', 'holiday_flg', 'days_until_holiday', 'days_since_holiday',
                     'air_genre_name', 'air_area_name', 'latitude', 'longitude', 'min_visitors', 'mean_visitors',
                     'median_visitors', 'max_visitors', 'count_observations']

# %%
x_testWk1_pred = testWk1_pred.drop(['id','air_store_id','visit_date','visitors'],axis=1)
x_testWk1_pred = x_testWk1_pred[columnsForTest_df]

# %%
d_test = xgb.DMatrix(x_testWk1_pred)
#del x_test; gc.collect()

# %%
print('Predicting on test ...')
p_test = clf.predict(d_test)
del d_test; gc.collect()
# Out:
# Predicting on test ...
# 136

# %%
testWk1_pred['visitors'] = np.expm1(p_test)
testWk1_pred[['id','visitors']].to_csv('xgb_submission_Wk1.csv', index=False, float_format='%.3f')

# %% [markdown]
# ### With test set Week 1 predicted, update ewma and assign to week 2

# %%
train_testWk1_concat = testWk1_pred[train.columns]
train_testWk1_concat = pd.concat([train, train_testWk1_concat])
train_testWk1_concat = train_testWk1_concat.reset_index()
tmp = train_testWk1_concat.groupby(['air_store_id','dow']).apply(lambda x: calc_shifted_ewm(x['visitors'],0.1))
tmp = tmp.fillna(method='bfill')
tmp.index = tmp.index.get_level_values(2)
tmp = tmp.sort_index()

# %%
train_testWk1_concat['ewma'] = tmp

# %%
tmp = train_testWk1_concat[train_testWk1_concat['visit_date'] > testWk2.visit_date.min() - pd.to_timedelta(1, unit='d')]
tmp = tmp[['air_store_id','visit_date','dow','ewma']]
testWk2_pred = pd.merge(testWk2, tmp.drop('visit_date',axis=1),how='left',on=['air_store_id','dow'])
testWk2_pred['ewma'] = testWk2_pred['ewma'].fillna(value=0)

# %%
x_testWk2_pred = testWk2_pred.drop(['id','air_store_id','visit_date','visitors'],axis=1)
x_testWk2_pred = x_testWk2_pred[columnsForTest_df]
#x_testWk2_pred.columns

# %%
d_test = xgb.DMatrix(x_testWk2_pred)
#del x_test; gc.collect()

# %%
print('Predictin on test ...')
p_test = clf.predict(d_test)
del d_test; gc.collect()
# Out:
# Predictin on test ...
# 96

# %%
testWk2_pred['visitors'] = np.expm1(p_test)
testWk2_pred[['id','visitors']].to_csv('xgb_submission_Wk2.csv',index=False,float_format='%.3f')

# %% [markdown]
# ### With test set Week 2 predicted, update ewma and assign to week 3

# %%
train_testWk2_concat = testWk2_pred[train.columns]
train_testWk2_concat = pd.concat([train_testWk1_concat, train_testWk2_concat])
train_testWk2_concat = train_testWk2_concat.reset_index()
tmp = train_testWk2_concat.groupby(['air_store_id','dow']).apply(lambda x: calc_shifted_ewm(x['visitors'],0.1))
tmp = tmp.fillna(method='bfill')
tmp.index = tmp.index.get_level_values(2)
tmp = tmp.sort_index()

# %%
train_testWk2_concat['ewma'] = tmp

# %%
tmp = train_testWk2_concat[train_testWk2_concat['visit_date'] > testWk3.visit_date.min() - pd.to_timedelta(1, unit='d')]
tmp = tmp[['air_store_id','visit_date','dow','ewma']]
testWk3_pred = pd.merge(testWk3, tmp.drop('visit_date',axis=1),how='left',on=['air_store_id','dow'])
testWk3_pred['ewma'] = testWk3_pred['ewma'].fillna(value=0)

# %%
x_testWk3_pred = testWk3_pred.drop(['id','air_store_id','visit_date','visitors'],axis=1)
x_testWk3_pred = x_testWk3_pred[columnsForTest_df]

# %%
d_test = xgb.DMatrix(x_testWk3_pred)
#del x_test; gc.collect()

# %%
print('Predictin on test ...')
p_test = clf.predict(d_test)
del d_test; gc.collect()
# Out:
# Predictin on test ...
# 96

# %%
testWk3_pred['visitors'] = np.expm1(p_test)
testWk3_pred[['id','visitors']].to_csv('xgb_submission_Wk3.csv',index=False,float_format='%.3f')

# %% [markdown]
# ### With test set Week 3 predicted, update ewma and assign to week 4

# %%
train_testWk3_concat = pd.concat([train_testWk2_concat[train.columns], testWk3_pred[train.columns]])
train_testWk3_concat = train_testWk3_concat.reset_index()
tmp = train_testWk3_concat.groupby(['air_store_id','dow']).apply(lambda x: calc_shifted_ewm(x['visitors'],0.1))
tmp = tmp.fillna(method='bfill')
tmp.index = tmp.index.get_level_values(2)
tmp = tmp.sort_index()

# %%
train_testWk3_concat['ewma'] = tmp

# %%
tmp = train_testWk3_concat[train_testWk3_concat['visit_date'] > testWk4.visit_date.min() - pd.to_timedelta(1, unit='d')]
tmp = tmp[['air_store_id','visit_date','dow','ewma']]
testWk4_pred = pd.merge(testWk4, tmp.drop('visit_date',axis=1),how='left',on=['air_store_id','dow'])
testWk4_pred['ewma'] = testWk4_pred['ewma'].fillna(value=0)

# %%
x_testWk4_pred = testWk4_pred.drop(['id','air_store_id','visit_date','visitors'],axis=1)
x_testWk4_pred = x_testWk4_pred[columnsForTest_df]

# %%
d_test = xgb.DMatrix(x_testWk4_pred)
#del x_test; gc.collect()

# %%
print('Predictin on test ...')
p_test = clf.predict(d_test)
del d_test; gc.collect()
# Out:
# Predictin on test ...
# 96

# %%
testWk4_pred['visitors'] = np.expm1(p_test)
testWk4_pred[['id','visitors']].to_csv('xgb_submission_Wk4.csv',index=False,float_format='%.3f')

# %% [markdown]
# ### With test set Week 4 predicted, update ewma and assign to week 5

# %%
train_testWk4_concat = pd.concat([train_testWk3_concat[train.columns], testWk4_pred[train.columns]])
train_testWk4_concat = train_testWk4_concat.reset_index()
tmp = train_testWk4_concat.groupby(['air_store_id','dow']).apply(lambda x: calc_shifted_ewm(x['visitors'],0.1))
tmp = tmp.fillna(method='bfill')
tmp.index = tmp.index.get_level_values(2)
tmp = tmp.sort_index()

# %%
train_testWk4_concat['ewma'] = tmp

# %%
tmp = train_testWk4_concat[train_testWk4_concat['visit_date'] > testWk5.visit_date.min() - pd.to_timedelta(1, unit='d')]
tmp = tmp[['air_store_id','visit_date','dow','ewma']]
testWk5_pred = pd.merge(testWk5, tmp.drop('visit_date',axis=1),how='left',on=['air_store_id','dow'])
testWk5_pred['ewma'] = testWk5_pred['ewma'].fillna(value=0)

# %%
x_testWk5_pred = testWk5_pred.drop(['id','air_store_id','visit_date','visitors'],axis=1)
x_testWk5_pred = x_testWk5_pred[columnsForTest_df]

# %%
d_test = xgb.DMatrix(x_testWk5_pred)
#del x_test; gc.collect()

# %%
print('Predictin on test ...')
p_test = clf.predict(d_test)
del d_test; gc.collect()
# Out:
# Predictin on test ...
# 96

# %%
testWk5_pred['visitors'] = np.expm1(p_test)
testWk5_pred[['id','visitors']].to_csv('xgb_submission_Wk5.csv',index=False,float_format='%.3f')

# %% [markdown]
# ### With test set Week 5 predicted, update ewma and assign to week 6

# %%
train_testWk5_concat = pd.concat([train_testWk4_concat[train.columns], testWk5_pred[train.columns]])
train_testWk5_concat = train_testWk5_concat.reset_index()
tmp = train_testWk5_concat.groupby(['air_store_id','dow']).apply(lambda x: calc_shifted_ewm(x['visitors'],0.1))
tmp = tmp.fillna(method='bfill')
tmp.index = tmp.index.get_level_values(2)
tmp = tmp.sort_index()

# %%
train_testWk5_concat['ewma'] = tmp

# %%
tmp = train_testWk5_concat[train_testWk5_concat['visit_date'] > testWk6.visit_date.min() - pd.to_timedelta(1, unit='d')]
tmp = tmp[['air_store_id','visit_date','dow','ewma']]
testWk6_pred = pd.merge(testWk6, tmp.drop('visit_date',axis=1),how='left',on=['air_store_id','dow'])
testWk6_pred['ewma'] = testWk6_pred['ewma'].fillna(value=0)

# %%
x_testWk6_pred = testWk6_pred.drop(['id','air_store_id','visit_date','visitors'],axis=1)
x_testWk6_pred = x_testWk6_pred[columnsForTest_df]

# %%
d_test = xgb.DMatrix(x_testWk6_pred)
#del x_test; gc.collect()

# %%
print('Predictin on test ...')
p_test = clf.predict(d_test)
del d_test; gc.collect()
# Out:
# Predictin on test ...
# 96

# %%
testWk6_pred['visitors'] = np.expm1(p_test)
testWk6_pred[['id','visitors']].to_csv('xgb_submission_Wk6.csv',index=False,float_format='%.3f')

# %% [markdown]
# ### Compile all prediction csv and sort in order needed for submission

# %%
pred_wk1 = pd.read_csv('xgb_submission_Wk1.csv')
pred_wk2 = pd.read_csv('xgb_submission_Wk2.csv')
pred_wk3 = pd.read_csv('xgb_submission_Wk3.csv')
pred_wk4 = pd.read_csv('xgb_submission_Wk4.csv')
pred_wk5 = pd.read_csv('xgb_submission_Wk5.csv')
pred_wk6 = pd.read_csv('xgb_submission_Wk6.csv')

# %%
compiled_predictions = pd.concat([pred_wk1,pred_wk2,pred_wk3,pred_wk4,pred_wk5,pred_wk6]).sort_values(by='id')

# %%
compiled_predictions[['id','visitors']].to_csv('xgb_submission.csv',index=False,float_format='%.3f')

# %% [markdown]
# # Check tree characteristics for hyperparameter turning

# %%
def modelfit(alg, dtrain, predictors, useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain.get_labels())
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
            metrics='rmse', early_stopping_rounds=early_stopping_rounds, show_progress=False)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain['Disbursed'],eval_metric='auc')
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
        
    #Print model report:
    print "\nModel Report"
    print "Accuracy : %.4g" % metrics.accuracy_score(dtrain['Disbursed'].values, dtrain_predictions)
    print "AUC Score (Train): %f" % metrics.roc_auc_score(dtrain['Disbursed'], dtrain_predprob)
                    
    feat_imp = pd.Series(alg.booster().get_fscore()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')
    plt.ylabel('Feature Importance Score')

# %%
clf.get_xgb_params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-86eab26260dd> in <module>()
# ----> 1 clf.get_xgb_params()
#
# AttributeError: 'Booster' object has no attribute 'get_xgb_params'

# %%
y_train
# Out:
# array([ 3.25809654,  3.49650756,  3.40119738, ...,  3.29583687,
#         3.09104245,  3.61091791])
